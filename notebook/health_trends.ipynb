# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wealth_data = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\Social_Vulnerability_Index_2018_-_United_States__tract_20240928.csv')

wealth_data.head(5)
# Out:
#    ST    STATE ST_ABBR   COUNTY        FIPS  \
# 0   1  ALABAMA      AL  Calhoun  1015981901
# 1   1  ALABAMA      AL  Calhoun  1015981902
# 2   1  ALABAMA      AL  Calhoun  1015981903
# 3   1  ALABAMA      AL   Mobile  1097003605
# 4   1  ALABAMA      AL   Mobile  1097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0
#
#    M_TOTPOP  E_HU  ...  F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  \
# 0        12     0  ...     -999      -999      -999     -999          0
# 1        12     0  ...     -999      -999      -999     -999          0
# 2        12     0  ...     -999      -999      -999     -999          0
# 3       316     0  ...     -999         1      -999     -999         33
# 4        12     0  ...     -999      -999      -999     -999          0
#
#    M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP  \
# 0         12      -999.0      -999.0       656
# 1         12      -999.0      -999.0       146
# 2         12      -999.0      -999.0         0
# 3         36         3.7         4.1      5135
# 4         12      -999.0      -999.0         0
#
#                                                Shape
# 0  MULTIPOLYGON (((-86.01323399999995 33.68425800...
# 1  MULTIPOLYGON (((-86.01729599999999 33.69662100...
# 2  MULTIPOLYGON (((-85.78500899999995 33.66553500...
# 3  MULTIPOLYGON (((-88.19230199999998 30.69523500...
# 4  MULTIPOLYGON (((-88.05337499999997 30.50698700...
#
# [5 rows x 124 columns]

# %%
weath_data = pd.DataFrame(data=wealth_data)

# %%
wealth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72837 entries, 0 to 72836
# Columns: 124 entries, ST to Shape
# dtypes: float64(61), int64(58), object(5)
# memory usage: 68.9+ MB

# %%
wealth_data
# Out:
#        ST       STATE ST_ABBR             COUNTY         FIPS  \
# 0       1     ALABAMA      AL            Calhoun   1015981901
# 1       1     ALABAMA      AL            Calhoun   1015981902
# 2       1     ALABAMA      AL            Calhoun   1015981903
# 3       1     ALABAMA      AL             Mobile   1097003605
# 4       1     ALABAMA      AL             Mobile   1097990000
# ...    ..         ...     ...                ...          ...
# 72832  51    VIRGINIA      VA          Albemarle  51003010903
# 72833  51    VIRGINIA      VA         Montgomery  51121020202
# 72834  51    VIRGINIA      VA  Newport News City  51700030100
# 72835  53  WASHINGTON      WA               King  53033005302
# 72836  53  WASHINGTON      WA             Yakima  53077000100
#
#                                                LOCATION  AREA_SQMI  E_TOTPOP  \
# 0         Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1         Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2         Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3            Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4             Census Tract 9900, Mobile County, Alabama   0.000000         0
# ...                                                 ...        ...       ...
# 72832   Census Tract 109.03, Albemarle County, Virginia   0.378015      3159
# 72833  Census Tract 202.02, Montgomery County, Virginia   2.278257      2000
# 72834     Census Tract 301, Newport News city, Virginia   1.636259      4274
# 72835       Census Tract 53.02, King County, Washington   0.968062      5320
# 72836         Census Tract 1, Yakima County, Washington   1.136201      3170
#
#        M_TOTPOP  E_HU  ...  F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  \
# 0            12     0  ...     -999      -999      -999     -999          0
# 1            12     0  ...     -999      -999      -999     -999          0
# 2            12     0  ...     -999      -999      -999     -999          0
# 3           316     0  ...     -999         1      -999     -999         33
# 4            12     0  ...     -999      -999      -999     -999          0
# ...         ...   ...  ...      ...       ...       ...      ...        ...
# 72832       553    98  ...        1         1         4        6         67
# 72833       232  1140  ...        1         1         4        7        102
# 72834       612  1647  ...        1         1         4        9        436
# 72835       629   127  ...        1         1         4        7        267
# 72836       325  1047  ...        1         1         4       11        450
#
#        M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP  \
# 0             12      -999.0      -999.0       656
# 1             12      -999.0      -999.0       146
# 2             12      -999.0      -999.0         0
# 3             36         3.7         4.1      5135
# 4             12      -999.0      -999.0         0
# ...          ...         ...         ...       ...
# 72832         47         2.1         1.3     12094
# 72833         64         6.0         3.6      2222
# 72834        139        14.9         4.6      6558
# 72835         98         5.1         1.8     40043
# 72836        125        21.8         5.6     18952
#
#                                                    Shape
# 0      MULTIPOLYGON (((-86.01323399999995 33.68425800...
# 1      MULTIPOLYGON (((-86.01729599999999 33.69662100...
# 2      MULTIPOLYGON (((-85.78500899999995 33.66553500...
# 3      MULTIPOLYGON (((-88.19230199999998 30.69523500...
# 4      MULTIPOLYGON (((-88.05337499999997 30.50698700...
# ...                                                  ...
# 72832  MULTIPOLYGON (((-78.51643399999995 38.02923900...
# 72833  MULTIPOLYGON (((-80.44958399999997 37.20061200...
# 72834  MULTIPOLYGON (((-76.43529899999999 36.98216400...
# 72835  MULTIPOLYGON (((-122.31833899999997 47.6553730...
# 72836  MULTIPOLYGON (((-120.51994199999996 46.6045990...
#
# [72837 rows x 124 columns]

# %%
wealth_data_short = wealth_data[['STATE', 'ST_ABBR', 'E_TOTPOP', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_NOVEH', 'EP_POV', 'EP_UNEMP', 'EP_PCI', 'EP_NOHSDP', 'EP_AGE65', 'EP_AGE17', 'EP_SNGPNT', 'EP_MINRTY', 'EP_NOVEH', 'EPL_POV', 'EPL_UNEMP', 'EPL_PCI', 'EPL_NOHSDP', 'SPL_THEME1', 'RPL_THEME1', 'EPL_MINRTY', 'F_POV', 'F_UNEMP', 'F_PCI', 'F_NOHSDP', 'F_THEME1', 'F_MINRTY', 'F_LIMENG', 'F_THEME3', 'E_UNINSUR', 'EP_UNINSUR']]

# %% [markdown]
# # wealth_data_short

# %%
wealth_data_state = wealth_data_short.groupby(['STATE', 'ST_ABBR']).sum()[['E_TOTPOP', 'E_POV', 'E_UNEMP', 'E_UNINSUR']]
wealth_data_state
# Out:
#                               E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR
# STATE                ST_ABBR
# ALABAMA              AL        4864680   829400   147898     477474
# ALASKA               AK         738516    77865    28067     102956
# ARIZONA              AZ        6946685  1092192   210214     748306
# ARKANSAS             AR        2990671   510337    75774     265434
# CALIFORNIA           CA       39148760  5487141  1321502    3280167
# COLORADO             CO        5531141   590504   139326     441850
# CONNECTICUT          CT        3581504   348449   125909     196809
# DELAWARE             DE         949495   109798    28501      56491
# DISTRICT OF COLUMBIA DC         684498   109497    29373      27088
# FLORIDA              FL       20598139  2983851   622978    2744513
# GEORGIA              GA       10297484  1607714   322854    1389541
# HAWAII               HI        1422029   137516    32036      55624
# IDAHO                ID        1687809   228882    37672     183747
# ILLINOIS             IL       12821497  1635603   437139     928612
# INDIANA              IN        6637426   908359   180969     596543
# IOWA                 IA        3132499   353634    65216     152469
# KANSAS               KS        2908776   350280    65038     256512
# KENTUCKY             KY        4440204   772080   128358     265416
# LOUISIANA            LA        4663616   878394   149850     487112
# MAINE                ME        1332813   161743    32203     109641
# MARYLAND             MD        6003435   553496   181089     382130
# MASSACHUSETTS        MA        6830193   710305   203464     189470
# MICHIGAN             MI        9957488  1457008   321008     597044
# MINNESOTA            MN        5527358   547442   119218     254764
# MISSISSIPPI          MS        2988762   599795   110036     370357
# MISSOURI             MO        6090062   837930   155958     581002
# MONTANA              MT        1041732   139063    22433     104910
# NEBRASKA             NE        1904760   213790    36545     157831
# NEVADA               NV        2922849   393431   101748     344104
# NEW HAMPSHIRE        NH        1343622   102352    30392      86274
# NEW JERSEY           NJ        8881845   904132   285084     743045
# NEW MEXICO           NM        2092434   390295    58248     220410
# NEW YORK             NY       19618453  2797985   602636    1255168
# NORTH CAROLINA       NC       10155624  1523949   312610    1100719
# NORTH DAKOTA         ND         752201    79270    11689      54485
# OHIO                 OH       11641879  1645986   343232     743259
# OKLAHOMA             OK        3918137   607810    99087     545570
# OREGON               OR        4081943   565247   123485     293690
# PENNSYLVANIA         PA       12791181  1578949   379765     785624
# RHODE ISLAND         RI        1056611   133055    34479      54269
# SOUTH CAROLINA       SC        4955925   770632   153242     535224
# SOUTH DAKOTA         SD         864289   113144    16252      79489
# TENNESSEE            TN        6651089  1046508   191544     660872
# TEXAS                TX       27885195  4213938   743006    4764897
# UTAH                 UT        3045350   309904    58958     301761
# VERMONT              VT         624977    67034    13878      25362
# VIRGINIA             VA        8413774   893580   217670     755739
# WASHINGTON           WA        7294336   821621   198330     487856
# WEST VIRGINIA        WV        1829054   315464    53750     116826
# WISCONSIN            WI        5778394   668220   124792     329424
# WYOMING              WY         581836    63311    13685      64887

# %%
wealth_data_state['PCNT_POV'] = round(wealth_data_state['E_POV'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state['PCNT_UNEMP'] = round(wealth_data_state['E_UNEMP'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state['PCNT_UNINSUR'] = round(wealth_data_state['E_UNINSUR'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state
# Out:
#                               E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  PCNT_POV  \
# STATE                ST_ABBR
# ALABAMA              AL        4864680   829400   147898     477474      17.0
# ALASKA               AK         738516    77865    28067     102956      11.0
# ARIZONA              AZ        6946685  1092192   210214     748306      16.0
# ARKANSAS             AR        2990671   510337    75774     265434      17.0
# CALIFORNIA           CA       39148760  5487141  1321502    3280167      14.0
# COLORADO             CO        5531141   590504   139326     441850      11.0
# CONNECTICUT          CT        3581504   348449   125909     196809      10.0
# DELAWARE             DE         949495   109798    28501      56491      12.0
# DISTRICT OF COLUMBIA DC         684498   109497    29373      27088      16.0
# FLORIDA              FL       20598139  2983851   622978    2744513      14.0
# GEORGIA              GA       10297484  1607714   322854    1389541      16.0
# HAWAII               HI        1422029   137516    32036      55624      10.0
# IDAHO                ID        1687809   228882    37672     183747      14.0
# ILLINOIS             IL       12821497  1635603   437139     928612      13.0
# INDIANA              IN        6637426   908359   180969     596543      14.0
# IOWA                 IA        3132499   353634    65216     152469      11.0
# KANSAS               KS        2908776   350280    65038     256512      12.0
# KENTUCKY             KY        4440204   772080   128358     265416      17.0
# LOUISIANA            LA        4663616   878394   149850     487112      19.0
# MAINE                ME        1332813   161743    32203     109641      12.0
# MARYLAND             MD        6003435   553496   181089     382130       9.0
# MASSACHUSETTS        MA        6830193   710305   203464     189470      10.0
# MICHIGAN             MI        9957488  1457008   321008     597044      15.0
# MINNESOTA            MN        5527358   547442   119218     254764      10.0
# MISSISSIPPI          MS        2988762   599795   110036     370357      20.0
# MISSOURI             MO        6090062   837930   155958     581002      14.0
# MONTANA              MT        1041732   139063    22433     104910      13.0
# NEBRASKA             NE        1904760   213790    36545     157831      11.0
# NEVADA               NV        2922849   393431   101748     344104      13.0
# NEW HAMPSHIRE        NH        1343622   102352    30392      86274       8.0
# NEW JERSEY           NJ        8881845   904132   285084     743045      10.0
# NEW MEXICO           NM        2092434   390295    58248     220410      19.0
# NEW YORK             NY       19618453  2797985   602636    1255168      14.0
# NORTH CAROLINA       NC       10155624  1523949   312610    1100719      15.0
# NORTH DAKOTA         ND         752201    79270    11689      54485      11.0
# OHIO                 OH       11641879  1645986   343232     743259      14.0
# OKLAHOMA             OK        3918137   607810    99087     545570      16.0
# OREGON               OR        4081943   565247   123485     293690      14.0
# PENNSYLVANIA         PA       12791181  1578949   379765     785624      12.0
# RHODE ISLAND         RI        1056611   133055    34479      54269      13.0
# SOUTH CAROLINA       SC        4955925   770632   153242     535224      16.0
# SOUTH DAKOTA         SD         864289   113144    16252      79489      13.0
# TENNESSEE            TN        6651089  1046508   191544     660872      16.0
# TEXAS                TX       27885195  4213938   743006    4764897      15.0
# UTAH                 UT        3045350   309904    58958     301761      10.0
# VERMONT              VT         624977    67034    13878      25362      11.0
# VIRGINIA             VA        8413774   893580   217670     755739      11.0
# WASHINGTON           WA        7294336   821621   198330     487856      11.0
# WEST VIRGINIA        WV        1829054   315464    53750     116826      17.0
# WISCONSIN            WI        5778394   668220   124792     329424      12.0
# WYOMING              WY         581836    63311    13685      64887      11.0
#
#                               PCNT_UNEMP  PCNT_UNINSUR
# STATE                ST_ABBR
# ALABAMA              AL              3.0          10.0
# ALASKA               AK              4.0          14.0
# ARIZONA              AZ              3.0          11.0
# ARKANSAS             AR              3.0           9.0
# CALIFORNIA           CA              3.0           8.0
# COLORADO             CO              3.0           8.0
# CONNECTICUT          CT              4.0           5.0
# DELAWARE             DE              3.0           6.0
# DISTRICT OF COLUMBIA DC              4.0           4.0
# FLORIDA              FL              3.0          13.0
# GEORGIA              GA              3.0          13.0
# HAWAII               HI              2.0           4.0
# IDAHO                ID              2.0          11.0
# ILLINOIS             IL              3.0           7.0
# INDIANA              IN              3.0           9.0
# IOWA                 IA              2.0           5.0
# KANSAS               KS              2.0           9.0
# KENTUCKY             KY              3.0           6.0
# LOUISIANA            LA              3.0          10.0
# MAINE                ME              2.0           8.0
# MARYLAND             MD              3.0           6.0
# MASSACHUSETTS        MA              3.0           3.0
# MICHIGAN             MI              3.0           6.0
# MINNESOTA            MN              2.0           5.0
# MISSISSIPPI          MS              4.0          12.0
# MISSOURI             MO              3.0          10.0
# MONTANA              MT              2.0          10.0
# NEBRASKA             NE              2.0           8.0
# NEVADA               NV              3.0          12.0
# NEW HAMPSHIRE        NH              2.0           6.0
# NEW JERSEY           NJ              3.0           8.0
# NEW MEXICO           NM              3.0          11.0
# NEW YORK             NY              3.0           6.0
# NORTH CAROLINA       NC              3.0          11.0
# NORTH DAKOTA         ND              2.0           7.0
# OHIO                 OH              3.0           6.0
# OKLAHOMA             OK              3.0          14.0
# OREGON               OR              3.0           7.0
# PENNSYLVANIA         PA              3.0           6.0
# RHODE ISLAND         RI              3.0           5.0
# SOUTH CAROLINA       SC              3.0          11.0
# SOUTH DAKOTA         SD              2.0           9.0
# TENNESSEE            TN              3.0          10.0
# TEXAS                TX              3.0          17.0
# UTAH                 UT              2.0          10.0
# VERMONT              VT              2.0           4.0
# VIRGINIA             VA              3.0           9.0
# WASHINGTON           WA              3.0           7.0
# WEST VIRGINIA        WV              3.0           6.0
# WISCONSIN            WI              2.0           6.0
# WYOMING              WY              2.0          11.0

# %%
wealth_data_state_avg = wealth_data_short.groupby(['STATE', 'ST_ABBR']).mean()[['EP_POV', 'EP_UNEMP']]

# %%
wealth_data_state_avg
# Out:
#                                  EP_POV   EP_UNEMP
# STATE                ST_ABBR
# ALABAMA              AL       14.943390   3.453475
# ALASKA               AK       11.428743   8.151497
# ARIZONA              AZ        9.411861  -0.392202
# ARKANSAS             AR       17.547522   4.903061
# CALIFORNIA           CA        7.563151   0.567218
# COLORADO             CO        1.143235  -4.733867
# CONNECTICUT          CT        7.478193   3.287349
# DELAWARE             DE       -1.131797  -7.868203
# DISTRICT OF COLUMBIA DC       17.501676   8.947486
# FLORIDA              FL        3.334497  -4.934544
# GEORGIA              GA       12.173499   0.435860
# HAWAII               HI      -47.879758 -49.904834
# IDAHO                ID       14.810403   5.179530
# ILLINOIS             IL       13.068952   5.993720
# INDIANA              IN       14.476658   4.153780
# IOWA                 IA       10.075030   1.702788
# KANSAS               KS        0.553247  -9.595584
# KENTUCKY             KY       12.260000   0.591749
# LOUISIANA            LA        9.091228  -4.750088
# MAINE                ME        2.147324  -6.249577
# MARYLAND             MD        2.597350  -1.855444
# MASSACHUSETTS        MA        2.332271  -2.426305
# MICHIGAN             MI        6.455411  -0.851659
# MINNESOTA            MN        7.226497   1.113323
# MISSISSIPPI          MS       17.017700   3.205144
# MISSOURI             MO       12.843719   2.829720
# MONTANA              MT        6.868266  -2.901845
# NEBRASKA             NE        4.681767  -2.027068
# NEVADA               NV        0.830713  -5.935371
# NEW HAMPSHIRE        NH        1.745238  -2.711224
# NEW JERSEY           NJ        5.626919   1.008076
# NEW MEXICO           NM       -2.411824 -14.925451
# NEW YORK             NY        0.302242  -7.364166
# NORTH CAROLINA       NC        3.460401  -4.800912
# NORTH DAKOTA         ND       11.429756   2.913659
# OHIO                 OH       14.316011   3.736635
# OKLAHOMA             OK       17.519120   5.964532
# OREGON               OR       10.783937   2.552899
# PENNSYLVANIA         PA        7.826111  -0.545508
# RHODE ISLAND         RI        1.187243  -6.059259
# SOUTH CAROLINA       SC        2.963463  -5.807072
# SOUTH DAKOTA         SD       14.207658   4.010360
# TENNESSEE            TN        4.133868  -4.836740
# TEXAS                TX        9.646060  -0.218215
# UTAH                 UT        4.383503  -2.816156
# VERMONT              VT        5.785326  -1.370109
# VIRGINIA             VA       -1.887632  -7.867421
# WASHINGTON           WA        5.107221  -1.342779
# WEST VIRGINIA        WV       19.467562   7.340289
# WISCONSIN            WI        9.965401   1.001003
# WYOMING              WY        4.042424  -2.793182

# %%
chronic_disease = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\U.S._Chronic_Disease_Indicators__CDI___2023_Release.csv')
# Out:
# C:\Users\hayli\AppData\Local\Temp\ipykernel_41440\2803124408.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   chronic_disease = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\U.S._Chronic_Disease_Indicators__CDI___2023_Release.csv')

# %%
chronic_disease
# Out:
#          YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0             2014     2014           AR              Arkansas  SEDD; SID
# 1             2018     2018           CO              Colorado  SEDD; SID
# 2             2018     2018           DC  District of Columbia  SEDD; SID
# 3             2017     2017           GA               Georgia  SEDD; SID
# 4             2010     2010           MI              Michigan  SEDD; SID
# ...            ...      ...          ...                   ...        ...
# 1185671       2020     2020           WY               Wyoming      BRFSS
# 1185672       2020     2020           WY               Wyoming      BRFSS
# 1185673       2017     2017           IA                  Iowa      BRFSS
# 1185674       2020     2020           WY               Wyoming      BRFSS
# 1185675       2019     2019           RI          Rhode Island      BRFSS
#
#                 Topic                                           Question  \
# 0              Asthma                        Hospitalizations for asthma
# 1              Asthma                        Hospitalizations for asthma
# 2              Asthma                        Hospitalizations for asthma
# 3              Asthma                        Hospitalizations for asthma
# 4              Asthma                        Hospitalizations for asthma
# ...               ...                                                ...
# 1185671      Diabetes  Dilated eye examination among adults aged >= 1...
# 1185672  Older Adults  Proportion of older adults aged >= 65 years wh...
# 1185673     Arthritis  Activity limitation due to arthritis among adu...
# 1185674      Diabetes   Diabetes prevalence among women aged 18-44 years
# 1185675     Arthritis  Activity limitation due to arthritis among adu...
#
#          Response DataValueUnit            DataValueType  ... LocationID  \
# 0             NaN           NaN                   Number  ...          5
# 1             NaN           NaN                   Number  ...          8
# 2             NaN           NaN                   Number  ...         11
# 3             NaN           NaN                   Number  ...         13
# 4             NaN           NaN                   Number  ...         26
# ...           ...           ...                      ...  ...        ...
# 1185671       NaN             %  Age-adjusted Prevalence  ...         56
# 1185672       NaN             %         Crude Prevalence  ...         56
# 1185673       NaN             %  Age-adjusted Prevalence  ...         19
# 1185674       NaN             %         Crude Prevalence  ...         56
# 1185675       NaN             %         Crude Prevalence  ...         44
#
#          TopicID QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0            AST     AST3_1            NMBR                     GENDER
# 1            AST     AST3_1            NMBR                    OVERALL
# 2            AST     AST3_1            NMBR                    OVERALL
# 3            AST     AST3_1            NMBR                     GENDER
# 4            AST     AST3_1            NMBR                       RACE
# ...          ...        ...             ...                        ...
# 1185671      DIA     DIA7_0      AGEADJPREV                       RACE
# 1185672      OLD     OLD3_1         CRDPREV                       RACE
# 1185673      ART     ART2_1      AGEADJPREV                       RACE
# 1185674      DIA     DIA2_2         CRDPREV                       RACE
# 1185675      ART     ART2_1         CRDPREV                    OVERALL
#
#          StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                     GENM                       NaN               NaN
# 1                      OVR                       NaN               NaN
# 2                      OVR                       NaN               NaN
# 3                     GENF                       NaN               NaN
# 4                      HIS                       NaN               NaN
# ...                    ...                       ...               ...
# 1185671                WHT                       NaN               NaN
# 1185672                WHT                       NaN               NaN
# 1185673                HIS                       NaN               NaN
# 1185674                HIS                       NaN               NaN
# 1185675                OVR                       NaN               NaN
#
#          StratificationCategoryID3  StratificationID3
# 0                              NaN                NaN
# 1                              NaN                NaN
# 2                              NaN                NaN
# 3                              NaN                NaN
# 4                              NaN                NaN
# ...                            ...                ...
# 1185671                        NaN                NaN
# 1185672                        NaN                NaN
# 1185673                        NaN                NaN
# 1185674                        NaN                NaN
# 1185675                        NaN                NaN
#
# [1185676 rows x 34 columns]

# %%
chronic_disease_2018 = chronic_disease[chronic_disease['YearStart'] == 2018]
chronic_disease_2018
# Out:
#          YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 1             2018     2018           CO              Colorado  SEDD; SID
# 2             2018     2018           DC  District of Columbia  SEDD; SID
# 17            2018     2018           KS                Kansas       NVSS
# 106           2018     2018           PR           Puerto Rico  SEDD; SID
# 111           2018     2018           DC  District of Columbia  SEDD; SID
# ...            ...      ...          ...                   ...        ...
# 1185569       2018     2018           WY               Wyoming      BRFSS
# 1185577       2018     2018           WY               Wyoming      BRFSS
# 1185652       2018     2018           WY               Wyoming      BRFSS
# 1185661       2018     2018           WY               Wyoming      BRFSS
# 1185663       2018     2018           WY               Wyoming      BRFSS
#
#                                          Topic  \
# 1                                       Asthma
# 2                                       Asthma
# 17                                      Asthma
# 106      Chronic Obstructive Pulmonary Disease
# 111      Chronic Obstructive Pulmonary Disease
# ...                                        ...
# 1185569                                Tobacco
# 1185577                                Tobacco
# 1185652                                Tobacco
# 1185661                                Tobacco
# 1185663                                Tobacco
#
#                                                   Question  Response  \
# 1                              Hospitalizations for asthma       NaN
# 2                              Hospitalizations for asthma       NaN
# 17                                   Asthma mortality rate       NaN
# 106      Hospitalization for chronic obstructive pulmon...       NaN
# 111      Hospitalization for chronic obstructive pulmon...       NaN
# ...                                                    ...       ...
# 1185569  Quit attempts in the past year among current s...       NaN
# 1185577  Current smokeless tobacco use among adults age...       NaN
# 1185652  Current smokeless tobacco use among adults age...       NaN
# 1185661  Quit attempts in the past year among current s...       NaN
# 1185663  Current smokeless tobacco use among adults age...       NaN
#
#         DataValueUnit            DataValueType  ... LocationID  TopicID  \
# 1                 NaN                   Number  ...          8      AST
# 2                 NaN                   Number  ...         11      AST
# 17             Number                   Number  ...         20      AST
# 106               NaN                   Number  ...         72     COPD
# 111               NaN                   Number  ...         11     COPD
# ...               ...                      ...  ...        ...      ...
# 1185569             %  Age-adjusted Prevalence  ...         56      TOB
# 1185577             %  Age-adjusted Prevalence  ...         56      TOB
# 1185652             %         Crude Prevalence  ...         56      TOB
# 1185661             %         Crude Prevalence  ...         56      TOB
# 1185663             %         Crude Prevalence  ...         56      TOB
#
#         QuestionID DataValueTypeID  StratificationCategoryID1  \
# 1           AST3_1            NMBR                    OVERALL
# 2           AST3_1            NMBR                    OVERALL
# 17          AST4_1            NMBR                    OVERALL
# 106        COPD5_1            NMBR                    OVERALL
# 111        COPD5_2            NMBR                     GENDER
# ...            ...             ...                        ...
# 1185569     TOB3_0      AGEADJPREV                       RACE
# 1185577     TOB2_2      AGEADJPREV                       RACE
# 1185652     TOB2_2         CRDPREV                       RACE
# 1185661     TOB3_0         CRDPREV                     GENDER
# 1185663     TOB2_2         CRDPREV                       RACE
#
#          StratificationID1 StratificationCategoryID2 StratificationID2  \
# 1                      OVR                       NaN               NaN
# 2                      OVR                       NaN               NaN
# 17                     OVR                       NaN               NaN
# 106                    OVR                       NaN               NaN
# 111                   GENF                       NaN               NaN
# ...                    ...                       ...               ...
# 1185569                MRC                       NaN               NaN
# 1185577                OTH                       NaN               NaN
# 1185652                HIS                       NaN               NaN
# 1185661               GENF                       NaN               NaN
# 1185663                WHT                       NaN               NaN
#
#          StratificationCategoryID3  StratificationID3
# 1                              NaN                NaN
# 2                              NaN                NaN
# 17                             NaN                NaN
# 106                            NaN                NaN
# 111                            NaN                NaN
# ...                            ...                ...
# 1185569                        NaN                NaN
# 1185577                        NaN                NaN
# 1185652                        NaN                NaN
# 1185661                        NaN                NaN
# 1185663                        NaN                NaN
#
# [95780 rows x 34 columns]

# %%
chronic_disease_2018 = chronic_disease_2018[['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic', 'Question',	'DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt', 'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit','StratificationCategoryID1', 'StratificationID1']]

# %%
chronic_disease_2018_state = chronic_disease_2018.groupby(['LocationAbbr', 'LocationDesc', 'Topic', 'StratificationCategoryID1', 'StratificationID1']).mean(['LowConfidenceLimit', 'HighConfidenceLimit'])

# %%
chronic_disease_2018_state
# Out:
#                                                                                YearStart  \
# LocationAbbr LocationDesc Topic   StratificationCategoryID1 StratificationID1
# AK           Alaska       Alcohol GENDER                    GENF                  2018.0
#                                                             GENM                  2018.0
#                                   OVERALL                   OVR                   2018.0
#                                   RACE                      AIAN                  2018.0
#                                                             API                   2018.0
# ...                                                                                  ...
# WY           Wyoming      Tobacco RACE                      BLK                   2018.0
#                                                             HIS                   2018.0
#                                                             MRC                   2018.0
#                                                             OTH                   2018.0
#                                                             WHT                   2018.0
#
#                                                                                YearEnd  \
# LocationAbbr LocationDesc Topic   StratificationCategoryID1 StratificationID1
# AK           Alaska       Alcohol GENDER                    GENF                2018.0
#                                                             GENM                2018.0
#                                   OVERALL                   OVR                 2018.0
#                                   RACE                      AIAN                2018.0
#                                                             API                 2018.0
# ...                                                                                ...
# WY           Wyoming      Tobacco RACE                      BLK                 2018.0
#                                                             HIS                 2018.0
#                                                             MRC                 2018.0
#                                                             OTH                 2018.0
#                                                             WHT                 2018.0
#
#                                                                                DataValueAlt  \
# LocationAbbr LocationDesc Topic   StratificationCategoryID1 StratificationID1
# AK           Alaska       Alcohol GENDER                    GENF                  13.600000
#                                                             GENM                  15.563636
#                                   OVERALL                   OVR                   20.713333
#                                   RACE                      AIAN                  40.200000
#                                                             API                   42.100000
# ...                                                                                     ...
# WY           Wyoming      Tobacco RACE                      BLK                         NaN
#                                                             HIS                   27.575000
#                                                             MRC                         NaN
#                                                             OTH                   24.175000
#                                                             WHT                   29.925000
#
#                                                                                LowConfidenceLimit  \
# LocationAbbr LocationDesc Topic   StratificationCategoryID1 StratificationID1
# AK           Alaska       Alcohol GENDER                    GENF                         6.820000
#                                                             GENM                         8.890000
#                                   OVERALL                   OVR                         12.300000
#                                   RACE                      AIAN                        30.766667
#                                                             API                         29.300000
# ...                                                                                           ...
# WY           Wyoming      Tobacco RACE                      BLK                               NaN
#                                                             HIS                         20.150000
#                                                             MRC                               NaN
#                                                             OTH                         15.200000
#                                                             WHT                         25.341667
#
#                                                                                HighConfidenceLimit
# LocationAbbr LocationDesc Topic   StratificationCategoryID1 StratificationID1
# AK           Alaska       Alcohol GENDER                    GENF                         11.750000
#                                                             GENM                         13.340000
#                                   OVERALL                   OVR                          16.761538
#                                   RACE                      AIAN                         50.366667
#                                                             API                          56.000000
# ...                                                                                            ...
# WY           Wyoming      Tobacco RACE                      BLK                                NaN
#                                                             HIS                          36.512500
#                                                             MRC                                NaN
#                                                             OTH                          36.350000
#                                                             WHT                          34.675000
#
# [8258 rows x 5 columns]

# %%
death_count = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2014-2019_20241003.csv')

# %%
death_count
# Out:
#       Jurisdiction of Occurrence  MMWR Year  MMWR Week Week Ending Date  \
# 0                        Florida       2014         43       10/25/2014
# 1                        Florida       2014         44       11/01/2014
# 2                        Florida       2014         45       11/08/2014
# 3                        Florida       2014         46       11/15/2014
# 4                        Florida       2014         47       11/22/2014
# ...                          ...        ...        ...              ...
# 16897                Puerto Rico       2019         48       11/30/2019
# 16898                Puerto Rico       2019         49       12/07/2019
# 16899                Puerto Rico       2019         50       12/14/2019
# 16900                Puerto Rico       2019         51       12/21/2019
# 16901                Puerto Rico       2019         52       12/28/2019
#
#        All  Cause  Natural Cause  Septicemia (A40-A41)  \
# 0            3381           3149                  38.0
# 1            3501           3261                  43.0
# 2            3646           3369                  44.0
# 3            3615           3346                  43.0
# 4            3672           3383                  39.0
# ...           ...            ...                   ...
# 16897         619            568                   NaN
# 16898         555            530                  15.0
# 16899         526            492                   NaN
# 16900         577            533                  17.0
# 16901         553            511                  11.0
#
#        Malignant neoplasms (C00-C97)  Diabetes mellitus (E10-E14)  \
# 0                              854.0                         81.0
# 1                              859.0                         85.0
# 2                              838.0                        121.0
# 3                              828.0                        110.0
# 4                              824.0                        109.0
# ...                              ...                          ...
# 16897                          113.0                         62.0
# 16898                          109.0                         62.0
# 16899                           91.0                         56.0
# 16900                           92.0                         59.0
# 16901                           96.0                         53.0
#
#        Alzheimer disease (G30)  ...  flag_neopl  flag_diab  flag_alz  \
# 0                        112.0  ...         NaN        NaN       NaN
# 1                        130.0  ...         NaN        NaN       NaN
# 2                        140.0  ...         NaN        NaN       NaN
# 3                        133.0  ...         NaN        NaN       NaN
# 4                        135.0  ...         NaN        NaN       NaN
# ...                        ...  ...         ...        ...       ...
# 16897                     53.0  ...         NaN        NaN       NaN
# 16898                     46.0  ...         NaN        NaN       NaN
# 16899                     39.0  ...         NaN        NaN       NaN
# 16900                     34.0  ...         NaN        NaN       NaN
# 16901                     39.0  ...         NaN        NaN       NaN
#
#                    flag_inflpn  flag_clrd           flag_otherresp  \
# 0                          NaN        NaN                      NaN
# 1                          NaN        NaN                      NaN
# 2                          NaN        NaN                      NaN
# 3                          NaN        NaN                      NaN
# 4                          NaN        NaN                      NaN
# ...                        ...        ...                      ...
# 16897                      NaN        NaN  Suppressed (counts 1-9)
# 16898  Suppressed (counts 1-9)        NaN  Suppressed (counts 1-9)
# 16899                      NaN        NaN  Suppressed (counts 1-9)
# 16900                      NaN        NaN                      NaN
# 16901                      NaN        NaN  Suppressed (counts 1-9)
#
#        flag_nephr            flag_otherunk  flag_hd flag_stroke
# 0             NaN                      NaN      NaN         NaN
# 1             NaN                      NaN      NaN         NaN
# 2             NaN                      NaN      NaN         NaN
# 3             NaN                      NaN      NaN         NaN
# 4             NaN                      NaN      NaN         NaN
# ...           ...                      ...      ...         ...
# 16897         NaN                      NaN      NaN         NaN
# 16898         NaN                      NaN      NaN         NaN
# 16899         NaN                      NaN      NaN         NaN
# 16900         NaN                      NaN      NaN         NaN
# 16901         NaN  Suppressed (counts 1-9)      NaN         NaN
#
# [16902 rows x 30 columns]

# %%
death_count = death_count.rename(columns={'Jurisdiction of Occurrence' : 'State', 'MMWR Year' : 'Year', 'MMWR Week': 'Week',	'Week Ending Date' : 'Week_End_Date', 'All Cause' : 'All_Causes',  'Natural Cause' : 'Natural_Cause', 'Septicemia (A40-A41)' : 'Septicemia', 'Malignant neoplasms (C00-C97)' : 'Malignant_Neoplasms', 'Diabetes mellitus (E10-E14)' : 'Diabetes', 'Alzheimer disease (G30)' : 'Alzheimer', 'Influenza and pneumonia (J10-J18)' : 'Flu_and_Pneumonia', 'Chronic lower respiratory diseases (J40-J47)' : 'Lower_Resp_Diseases', 'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)' : 'Other_Resp_Diseases',	'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)' : 'Nephritis', 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)' : 'Abnormal_Findings',	'Diseases of heart (I00-I09,I11,I13,I20-I51)' : 'Heart_Disease',	'Cerebrovascular diseases (I60-I69)' : 'Cerebrovascular_diseases'})

# %%
death_count
# Out:
#              State  Year  Week Week_End_Date  All  Cause  Natural_Cause  \
# 0          Florida  2014    43    10/25/2014        3381           3149
# 1          Florida  2014    44    11/01/2014        3501           3261
# 2          Florida  2014    45    11/08/2014        3646           3369
# 3          Florida  2014    46    11/15/2014        3615           3346
# 4          Florida  2014    47    11/22/2014        3672           3383
# ...            ...   ...   ...           ...         ...            ...
# 16897  Puerto Rico  2019    48    11/30/2019         619            568
# 16898  Puerto Rico  2019    49    12/07/2019         555            530
# 16899  Puerto Rico  2019    50    12/14/2019         526            492
# 16900  Puerto Rico  2019    51    12/21/2019         577            533
# 16901  Puerto Rico  2019    52    12/28/2019         553            511
#
#        Septicemia  Malignant_Neoplasms  Diabetes  Alzheimer  ...  flag_neopl  \
# 0            38.0                854.0      81.0      112.0  ...         NaN
# 1            43.0                859.0      85.0      130.0  ...         NaN
# 2            44.0                838.0     121.0      140.0  ...         NaN
# 3            43.0                828.0     110.0      133.0  ...         NaN
# 4            39.0                824.0     109.0      135.0  ...         NaN
# ...           ...                  ...       ...        ...  ...         ...
# 16897         NaN                113.0      62.0       53.0  ...         NaN
# 16898        15.0                109.0      62.0       46.0  ...         NaN
# 16899         NaN                 91.0      56.0       39.0  ...         NaN
# 16900        17.0                 92.0      59.0       34.0  ...         NaN
# 16901        11.0                 96.0      53.0       39.0  ...         NaN
#
#        flag_diab  flag_alz              flag_inflpn  flag_clrd  \
# 0            NaN       NaN                      NaN        NaN
# 1            NaN       NaN                      NaN        NaN
# 2            NaN       NaN                      NaN        NaN
# 3            NaN       NaN                      NaN        NaN
# 4            NaN       NaN                      NaN        NaN
# ...          ...       ...                      ...        ...
# 16897        NaN       NaN                      NaN        NaN
# 16898        NaN       NaN  Suppressed (counts 1-9)        NaN
# 16899        NaN       NaN                      NaN        NaN
# 16900        NaN       NaN                      NaN        NaN
# 16901        NaN       NaN                      NaN        NaN
#
#                 flag_otherresp  flag_nephr            flag_otherunk  flag_hd  \
# 0                          NaN         NaN                      NaN      NaN
# 1                          NaN         NaN                      NaN      NaN
# 2                          NaN         NaN                      NaN      NaN
# 3                          NaN         NaN                      NaN      NaN
# 4                          NaN         NaN                      NaN      NaN
# ...                        ...         ...                      ...      ...
# 16897  Suppressed (counts 1-9)         NaN                      NaN      NaN
# 16898  Suppressed (counts 1-9)         NaN                      NaN      NaN
# 16899  Suppressed (counts 1-9)         NaN                      NaN      NaN
# 16900                      NaN         NaN                      NaN      NaN
# 16901  Suppressed (counts 1-9)         NaN  Suppressed (counts 1-9)      NaN
#
#       flag_stroke
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 16897         NaN
# 16898         NaN
# 16899         NaN
# 16900         NaN
# 16901         NaN
#
# [16902 rows x 30 columns]

# %%
death_count_2018 = death_count[['Year'] == 2018]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 death_count_2018 = death_count[['Year'] == 2018]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: False
