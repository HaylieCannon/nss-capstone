# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wealth_data = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\Social_Vulnerability_Index_2018_-_United_States__tract_20240928.csv')

wealth_data.head(5)
# Out:
#    ST    STATE ST_ABBR   COUNTY        FIPS  \
# 0   1  ALABAMA      AL  Calhoun  1015981901
# 1   1  ALABAMA      AL  Calhoun  1015981902
# 2   1  ALABAMA      AL  Calhoun  1015981903
# 3   1  ALABAMA      AL   Mobile  1097003605
# 4   1  ALABAMA      AL   Mobile  1097990000
#
#                                         LOCATION  AREA_SQMI  E_TOTPOP  \
# 0  Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# 1  Census Tract 9819.02, Calhoun County, Alabama  34.646714         0
# 2  Census Tract 9819.03, Calhoun County, Alabama  13.926276         0
# 3     Census Tract 36.05, Mobile County, Alabama   0.732300       899
# 4      Census Tract 9900, Mobile County, Alabama   0.000000         0
#
#    M_TOTPOP  E_HU  ...  F_NOVEH  F_GROUPQ  F_THEME4  F_TOTAL  E_UNINSUR  \
# 0        12     0  ...     -999      -999      -999     -999          0
# 1        12     0  ...     -999      -999      -999     -999          0
# ...

# %%
weath_data = pd.DataFrame(data=wealth_data)

# %%
wealth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72837 entries, 0 to 72836
# Columns: 124 entries, ST to Shape
# dtypes: float64(61), int64(58), object(5)
# memory usage: 68.9+ MB

# %%
wealth_data
# Out:
#        ST       STATE ST_ABBR             COUNTY         FIPS  \
# 0       1     ALABAMA      AL            Calhoun   1015981901
# 1       1     ALABAMA      AL            Calhoun   1015981902
# 2       1     ALABAMA      AL            Calhoun   1015981903
# 3       1     ALABAMA      AL             Mobile   1097003605
# 4       1     ALABAMA      AL             Mobile   1097990000
# ...    ..         ...     ...                ...          ...
# 72832  51    VIRGINIA      VA          Albemarle  51003010903
# 72833  51    VIRGINIA      VA         Montgomery  51121020202
# 72834  51    VIRGINIA      VA  Newport News City  51700030100
# 72835  53  WASHINGTON      WA               King  53033005302
# 72836  53  WASHINGTON      WA             Yakima  53077000100
#
#                                                LOCATION  AREA_SQMI  E_TOTPOP  \
# 0         Census Tract 9819.01, Calhoun County, Alabama  24.243865         0
# ...

# %%
wealth_data_short = wealth_data[['STATE', 'ST_ABBR', 'E_TOTPOP', 'E_POV', 'E_UNEMP', 'E_PCI', 'E_NOHSDP', 'E_SNGPNT', 'E_MINRTY', 'E_LIMENG', 'E_NOVEH', 'EP_POV', 'EP_UNEMP', 'EP_PCI', 'EP_NOHSDP', 'EP_AGE65', 'EP_AGE17', 'EP_SNGPNT', 'EP_MINRTY', 'EP_NOVEH', 'EPL_POV', 'EPL_UNEMP', 'EPL_PCI', 'EPL_NOHSDP', 'SPL_THEME1', 'RPL_THEME1', 'EPL_MINRTY', 'F_POV', 'F_UNEMP', 'F_PCI', 'F_NOHSDP', 'F_THEME1', 'F_MINRTY', 'F_LIMENG', 'F_THEME3', 'E_UNINSUR', 'EP_UNINSUR']]

# %%
wealth_data_short
# Out:
#             STATE ST_ABBR  E_TOTPOP  E_POV  E_UNEMP  E_PCI  E_NOHSDP  \
# 0         ALABAMA      AL         0      0        0   -999         0
# 1         ALABAMA      AL         0      0        0   -999         0
# 2         ALABAMA      AL         0      0        0   -999         0
# 3         ALABAMA      AL       899      0       40   2651         0
# 4         ALABAMA      AL         0      0        0   -999         0
# ...           ...     ...       ...    ...      ...    ...       ...
# 72832    VIRGINIA      VA      3159    164       62   4089        44
# 72833    VIRGINIA      VA      2000    307      116  31675       242
# 72834    VIRGINIA      VA      4274   1324      251  13370       575
# 72835  WASHINGTON      WA      5320    108      299   4155        27
# 72836  WASHINGTON      WA      3170    847      104  11406       845
#
#        E_SNGPNT  E_MINRTY  E_LIMENG  ...  F_POV  F_UNEMP  F_PCI  F_NOHSDP  \
# ...

# %%
wealth_data_state = wealth_data_short.groupby(['STATE', 'ST_ABBR']).sum()[['E_TOTPOP', 'E_POV', 'E_UNEMP', 'E_UNINSUR']].reset_index()
wealth_data_state
# Out:
#                    STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR
# 0                ALABAMA      AL   4864680   829400   147898     477474
# 1                 ALASKA      AK    738516    77865    28067     102956
# 2                ARIZONA      AZ   6946685  1092192   210214     748306
# 3               ARKANSAS      AR   2990671   510337    75774     265434
# 4             CALIFORNIA      CA  39148760  5487141  1321502    3280167
# 5               COLORADO      CO   5531141   590504   139326     441850
# 6            CONNECTICUT      CT   3581504   348449   125909     196809
# 7               DELAWARE      DE    949495   109798    28501      56491
# 8   DISTRICT OF COLUMBIA      DC    684498   109497    29373      27088
# 9                FLORIDA      FL  20598139  2983851   622978    2744513
# 10               GEORGIA      GA  10297484  1607714   322854    1389541
# 11                HAWAII      HI   1422029   137516    32036      55624
# ...

# %%
wealth_data_state['STATE'] = wealth_data_state['STATE'].str.title()

# %%
wealth_data_state['PCNT_POV'] = round(wealth_data_state['E_POV'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state['PCNT_UNEMP'] = round(wealth_data_state['E_UNEMP'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state['PCNT_UNINSUR'] = round(wealth_data_state['E_UNINSUR'] / wealth_data_state['E_TOTPOP']*100)

# %%
wealth_data_state
# Out:
#                    STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  \
# 0                Alabama      AL   4864680   829400   147898     477474
# 1                 Alaska      AK    738516    77865    28067     102956
# 2                Arizona      AZ   6946685  1092192   210214     748306
# 3               Arkansas      AR   2990671   510337    75774     265434
# 4             California      CA  39148760  5487141  1321502    3280167
# 5               Colorado      CO   5531141   590504   139326     441850
# 6            Connecticut      CT   3581504   348449   125909     196809
# 7               Delaware      DE    949495   109798    28501      56491
# 8   District Of Columbia      DC    684498   109497    29373      27088
# 9                Florida      FL  20598139  2983851   622978    2744513
# 10               Georgia      GA  10297484  1607714   322854    1389541
# 11                Hawaii      HI   1422029   137516    32036      55624
# ...

# %%
#wealth_data_state.to_csv('wealth_data_state.csv')

# %%
bottom_5_population = wealth_data_state[['STATE', 'E_TOTPOP']].sort_values('E_TOTPOP', ascending=True).head(10)
bottom_5_population
# Out:
#                    STATE  E_TOTPOP
# 50               Wyoming    581836
# 45               Vermont    624977
# 8   District Of Columbia    684498
# 1                 Alaska    738516
# 34          North Dakota    752201
# 41          South Dakota    864289
# 7               Delaware    949495
# 26               Montana   1041732
# 39          Rhode Island   1056611
# 19                 Maine   1332813

# %%
top_5_population = wealth_data_state[['STATE', 'E_TOTPOP']].sort_values('E_TOTPOP', ascending=False).head(10)
top_5_population
# Out:
#              STATE  E_TOTPOP
# 4       California  39148760
# 43           Texas  27885195
# 9          Florida  20598139
# 32        New York  19618453
# 13        Illinois  12821497
# 38    Pennsylvania  12791181
# 35            Ohio  11641879
# 10         Georgia  10297484
# 33  North Carolina  10155624
# 22        Michigan   9957488

# %%
top_5_wealthy = wealth_data_state[['STATE', 'PCNT_POV']].sort_values('PCNT_POV', ascending=False).head(5)
top_5_wealthy
# Out:
#           STATE  PCNT_POV
# 24  Mississippi      20.0
# 18    Louisiana      19.0
# 31   New Mexico      19.0
# 17     Kentucky      17.0
# 0       Alabama      17.0

# %%
top_5_poverty = wealth_data_state[['STATE', 'PCNT_POV']].sort_values('PCNT_POV', ascending=True).head(5)
top_5_poverty
# Out:
#             STATE  PCNT_POV
# 29  New Hampshire       8.0
# 20       Maryland       9.0
# 30     New Jersey      10.0
# 23      Minnesota      10.0
# 21  Massachusetts      10.0

# %%
top_5_unemployed = wealth_data_state[['STATE', 'PCNT_UNEMP']].sort_values('PCNT_UNEMP', ascending=False).head(5)
top_5_unemployed
# Out:
#                    STATE  PCNT_UNEMP
# 24           Mississippi         4.0
# 1                 Alaska         4.0
# 6            Connecticut         4.0
# 8   District Of Columbia         4.0
# 37                Oregon         3.0

# %%
top_5_employed = wealth_data_state[['STATE', 'PCNT_UNEMP']].sort_values('PCNT_UNEMP', ascending=True).head(5)
top_5_employed
# Out:
#         STATE  PCNT_UNEMP
# 50    Wyoming         2.0
# 27   Nebraska         2.0
# 26    Montana         2.0
# 49  Wisconsin         2.0
# 23  Minnesota         2.0

# %%
top_5_uninsured = wealth_data_state[['STATE', 'PCNT_UNINSUR']].sort_values('PCNT_UNINSUR', ascending=False).head(5)
top_5_uninsured
# Out:
#        STATE  PCNT_UNINSUR
# 43     Texas          17.0
# 1     Alaska          14.0
# 36  Oklahoma          14.0
# 9    Florida          13.0
# 10   Georgia          13.0

# %%
top_5_insured = wealth_data_state[['STATE', 'PCNT_UNINSUR']].sort_values('PCNT_UNINSUR', ascending=True).head(5)
top_5_insured
# Out:
#                    STATE  PCNT_UNINSUR
# 21         Massachusetts           3.0
# 11                Hawaii           4.0
# 8   District Of Columbia           4.0
# 45               Vermont           4.0
# 39          Rhode Island           5.0

# %%
chronic_disease = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\U.S._Chronic_Disease_Indicators__CDI___2023_Release.csv')
# Out:
# C:\Users\hayli\AppData\Local\Temp\ipykernel_28768\2803124408.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   chronic_disease = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\U.S._Chronic_Disease_Indicators__CDI___2023_Release.csv')

# %%
chronic_disease
# Out:
#          YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 0             2014     2014           AR              Arkansas  SEDD; SID
# 1             2018     2018           CO              Colorado  SEDD; SID
# 2             2018     2018           DC  District of Columbia  SEDD; SID
# 3             2017     2017           GA               Georgia  SEDD; SID
# 4             2010     2010           MI              Michigan  SEDD; SID
# ...            ...      ...          ...                   ...        ...
# 1185671       2020     2020           WY               Wyoming      BRFSS
# 1185672       2020     2020           WY               Wyoming      BRFSS
# 1185673       2017     2017           IA                  Iowa      BRFSS
# 1185674       2020     2020           WY               Wyoming      BRFSS
# 1185675       2019     2019           RI          Rhode Island      BRFSS
#
#                 Topic                                           Question  \
# ...

# %%
chronic_disease = chronic_disease[['YearStart', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt', 'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit','StratificationCategoryID1', 'StratificationID1']]

# %%
chronic_disease = chronic_disease[chronic_disease['LocationDesc'] != 'United States']

# %%
chronic_disease = chronic_disease[chronic_disease['LocationDesc'] != 'Virgin Islands']

# %%
chronic_disease = chronic_disease[chronic_disease['LocationDesc'] != 'Guam']

# %%
chronic_disease = chronic_disease[chronic_disease['LocationDesc'] != 'Puerto Rico']

# %%
Heart_issues_all_years = chronic_disease[chronic_disease['Topic'] == "Cardiovascular Disease"]
Heart_issues_all_years
# Out:
#          YearStart LocationAbbr   LocationDesc DataSource  \
# 132           2016           ID          Idaho       NVSS
# 133           2012           MA  Massachusetts       NVSS
# 134           2014           MD       Maryland       NVSS
# 135           2014           MS    Mississippi       NVSS
# 136           2011           SD   South Dakota       NVSS
# ...            ...          ...            ...        ...
# 1185476       2020           WY        Wyoming      BRFSS
# 1185477       2020           WY        Wyoming      BRFSS
# 1185528       2020           WY        Wyoming      BRFSS
# 1185637       2020           WY        Wyoming      BRFSS
# 1185662       2020           WY        Wyoming      BRFSS
#
#                           Topic  \
# 132      Cardiovascular Disease
# 133      Cardiovascular Disease
# 134      Cardiovascular Disease
# 135      Cardiovascular Disease
# 136      Cardiovascular Disease
# ...                         ...
# 1185476  Cardiovascular Disease
# ...

# %%
Heart_issues_all_years = Heart_issues_all_years.rename(columns={'YearStart' : 'Year'})

# %%
Heart_issues_100000_all = Heart_issues_all_years[Heart_issues_all_years['DataValueUnit'] == "cases per 100,000"]
Heart_issues_100000_all
# Out:
#         Year LocationAbbr LocationDesc DataSource                   Topic  \
# 266745  2014           GA      Georgia       NVSS  Cardiovascular Disease
# 266890  2020           AK       Alaska       NVSS  Cardiovascular Disease
# 267500  2016           LA    Louisiana       NVSS  Cardiovascular Disease
# 268033  2011           ME        Maine       NVSS  Cardiovascular Disease
# 268304  2015           ID        Idaho       NVSS  Cardiovascular Disease
# ...      ...          ...          ...        ...                     ...
# 389743  2017           WY      Wyoming       NVSS  Cardiovascular Disease
# 389752  2010           WI    Wisconsin       NVSS  Cardiovascular Disease
# 389765  2015           WA   Washington       NVSS  Cardiovascular Disease
# 389776  2020           WY      Wyoming       NVSS  Cardiovascular Disease
# 389780  2010           WA   Washington       NVSS  Cardiovascular Disease
#
#                                                Question      DataValueUnit  \
# ...

# %%
Heart_issues_overall_all_years = Heart_issues_100000_all[Heart_issues_100000_all['StratificationCategoryID1'] == "OVERALL"]
Heart_issues_overall_all_years
# Out:
#         Year LocationAbbr LocationDesc DataSource                   Topic  \
# 266890  2020           AK       Alaska       NVSS  Cardiovascular Disease
# 267500  2016           LA    Louisiana       NVSS  Cardiovascular Disease
# 268977  2018           FL      Florida       NVSS  Cardiovascular Disease
# 269142  2015           IA         Iowa       NVSS  Cardiovascular Disease
# 269763  2010           GA      Georgia       NVSS  Cardiovascular Disease
# ...      ...          ...          ...        ...                     ...
# 388937  2011           WY      Wyoming       NVSS  Cardiovascular Disease
# 389327  2020           WY      Wyoming       NVSS  Cardiovascular Disease
# 389516  2020           WA   Washington       NVSS  Cardiovascular Disease
# 389735  2015           WI    Wisconsin       NVSS  Cardiovascular Disease
# 389765  2015           WA   Washington       NVSS  Cardiovascular Disease
#
#                                                Question      DataValueUnit  \
# ...

# %%
Heart_issues_all_years_adjusted = Heart_issues_overall_all_years[Heart_issues_overall_all_years['DataValueType'] == "Age-adjusted Rate"]
Heart_issues_all_years_adjusted
# Out:
#         Year LocationAbbr   LocationDesc DataSource                   Topic  \
# 267500  2016           LA      Louisiana       NVSS  Cardiovascular Disease
# 268977  2018           FL        Florida       NVSS  Cardiovascular Disease
# 269763  2010           GA        Georgia       NVSS  Cardiovascular Disease
# 273430  2017           FL        Florida       NVSS  Cardiovascular Disease
# 276777  2011           AL        Alabama       NVSS  Cardiovascular Disease
# ...      ...          ...            ...        ...                     ...
# 388759  2011           WV  West Virginia       NVSS  Cardiovascular Disease
# 388779  2011           WI      Wisconsin       NVSS  Cardiovascular Disease
# 388937  2011           WY        Wyoming       NVSS  Cardiovascular Disease
# 389735  2015           WI      Wisconsin       NVSS  Cardiovascular Disease
# 389765  2015           WA     Washington       NVSS  Cardiovascular Disease
#
# ...

# %%
Heart_issues_all_years_group = Heart_issues_all_years_adjusted.groupby(['LocationDesc', 'Year']).mean(numeric_only=True).reset_index()
Heart_issues_all_years_group
# Out:
#     LocationDesc  Year  DataValueAlt  LowConfidenceLimit  HighConfidenceLimit
# 0        Alabama  2010        163.64              160.28               167.02
# 1        Alabama  2011        157.74              154.46               161.02
# 2        Alabama  2012        155.10              151.84               158.32
# 3        Alabama  2013        156.26              153.04               159.44
# 4        Alabama  2014        152.56              149.44               155.70
# ..           ...   ...           ...                 ...                  ...
# 556      Wyoming  2016        114.42              106.44               122.38
# 557      Wyoming  2017        108.38              100.70               116.10
# 558      Wyoming  2018        114.28              106.46               122.12
# 559      Wyoming  2019        111.78              104.12               119.40
# 560      Wyoming  2020        118.24              110.52               125.94
#
# [561 rows x 5 columns]

# %%
#Heart_issues_all_years_group.to_csv('Heart_issues_all_years_group.csv')

# %%
chronic_disease_2018 = chronic_disease[chronic_disease['YearStart'] == 2018]
chronic_disease_2018
# Out:
#          YearStart LocationAbbr          LocationDesc DataSource  \
# 1             2018           CO              Colorado  SEDD; SID
# 2             2018           DC  District of Columbia  SEDD; SID
# 17            2018           KS                Kansas       NVSS
# 111           2018           DC  District of Columbia  SEDD; SID
# 112           2018           DE              Delaware  SEDD; SID
# ...            ...          ...                   ...        ...
# 1185569       2018           WY               Wyoming      BRFSS
# 1185577       2018           WY               Wyoming      BRFSS
# 1185652       2018           WY               Wyoming      BRFSS
# 1185661       2018           WY               Wyoming      BRFSS
# 1185663       2018           WY               Wyoming      BRFSS
#
#                                          Topic  \
# 1                                       Asthma
# 2                                       Asthma
# ...

# %%
chronic_disease_2018 = chronic_disease_2018[['YearStart', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue', 'DataValueAlt', 'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit','StratificationCategoryID1', 'StratificationID1']]

# %%
chronic_disease_2018 = chronic_disease_2018.rename(columns={'YearStart' : 'Year'})

# %%
chronic_disease_2018 = chronic_disease_2018[chronic_disease_2018['LocationDesc'] != 'United States']

# %%
chronic_disease_2018 = chronic_disease_2018[chronic_disease_2018['LocationDesc'] != 'Virgin Islands']

# %%
chronic_disease_2018 = chronic_disease_2018[chronic_disease_2018['LocationDesc'] != 'Guam']

# %%
chronic_disease_2018 = chronic_disease_2018[chronic_disease_2018['LocationDesc'] != 'Puerto Rico']

# %%
chronic_disease_2018
# Out:
#          Year LocationAbbr          LocationDesc DataSource  \
# 1        2018           CO              Colorado  SEDD; SID
# 2        2018           DC  District of Columbia  SEDD; SID
# 17       2018           KS                Kansas       NVSS
# 111      2018           DC  District of Columbia  SEDD; SID
# 112      2018           DE              Delaware  SEDD; SID
# ...       ...          ...                   ...        ...
# 1185569  2018           WY               Wyoming      BRFSS
# 1185577  2018           WY               Wyoming      BRFSS
# 1185652  2018           WY               Wyoming      BRFSS
# 1185661  2018           WY               Wyoming      BRFSS
# 1185663  2018           WY               Wyoming      BRFSS
#
#                                          Topic  \
# 1                                       Asthma
# 2                                       Asthma
# 17                                      Asthma
# 111      Chronic Obstructive Pulmonary Disease
# ...

# %%
Heart_issues_all = chronic_disease_2018[chronic_disease_2018['Topic'] == "Cardiovascular Disease"]
Heart_issues_all
# Out:
#          Year LocationAbbr LocationDesc DataSource                   Topic  \
# 137      2018           VA     Virginia       NVSS  Cardiovascular Disease
# 256700   2018           AZ      Arizona       NVSS  Cardiovascular Disease
# 258246   2018           AZ      Arizona       NVSS  Cardiovascular Disease
# 259405   2018           IN      Indiana       NVSS  Cardiovascular Disease
# 260723   2018           AZ      Arizona       NVSS  Cardiovascular Disease
# ...       ...          ...          ...        ...                     ...
# 1181931  2018           WY      Wyoming      BRFSS  Cardiovascular Disease
# 1182161  2018           WY      Wyoming      BRFSS  Cardiovascular Disease
# 1182324  2018           WY      Wyoming      BRFSS  Cardiovascular Disease
# 1182343  2018           WY      Wyoming      BRFSS  Cardiovascular Disease
# 1182437  2018           WY      Wyoming      BRFSS  Cardiovascular Disease
#
# ...

# %%
Heart_issues_100000 = Heart_issues_all[Heart_issues_all['DataValueUnit'] == "cases per 100,000"]
Heart_issues_100000
# Out:
#         Year LocationAbbr   LocationDesc DataSource                   Topic  \
# 268977  2018           FL        Florida       NVSS  Cardiovascular Disease
# 269598  2018           GA        Georgia       NVSS  Cardiovascular Disease
# 269838  2018           AL        Alabama       NVSS  Cardiovascular Disease
# 270775  2018           MA  Massachusetts       NVSS  Cardiovascular Disease
# 271200  2018           IA           Iowa       NVSS  Cardiovascular Disease
# ...      ...          ...            ...        ...                     ...
# 388363  2018           WV  West Virginia       NVSS  Cardiovascular Disease
# 388543  2018           WA     Washington       NVSS  Cardiovascular Disease
# 388941  2018           WY        Wyoming       NVSS  Cardiovascular Disease
# 389624  2018           WI      Wisconsin       NVSS  Cardiovascular Disease
# 389692  2018           WY        Wyoming       NVSS  Cardiovascular Disease
#
# ...

# %%
Heart_issues_overall = Heart_issues_100000[Heart_issues_100000['StratificationCategoryID1'] == "OVERALL"]
Heart_issues_overall
# Out:
#         Year LocationAbbr   LocationDesc DataSource                   Topic  \
# 268977  2018           FL        Florida       NVSS  Cardiovascular Disease
# 295380  2018           CA     California       NVSS  Cardiovascular Disease
# 303753  2018           MA  Massachusetts       NVSS  Cardiovascular Disease
# 304273  2018           AZ        Arizona       NVSS  Cardiovascular Disease
# 305178  2018           GA        Georgia       NVSS  Cardiovascular Disease
# ...      ...          ...            ...        ...                     ...
# 387794  2018           WI      Wisconsin       NVSS  Cardiovascular Disease
# 388018  2018           WV  West Virginia       NVSS  Cardiovascular Disease
# 388282  2018           WV  West Virginia       NVSS  Cardiovascular Disease
# 388300  2018           WY        Wyoming       NVSS  Cardiovascular Disease
# 388543  2018           WA     Washington       NVSS  Cardiovascular Disease
#
# ...

# %%
Heart_issues = Heart_issues_100000[Heart_issues_100000['DataValueType'] == "Age-adjusted Rate"]
Heart_issues
# Out:
#         Year LocationAbbr   LocationDesc DataSource                   Topic  \
# 268977  2018           FL        Florida       NVSS  Cardiovascular Disease
# 270775  2018           MA  Massachusetts       NVSS  Cardiovascular Disease
# 284818  2018           KS         Kansas       NVSS  Cardiovascular Disease
# 287311  2018           MD       Maryland       NVSS  Cardiovascular Disease
# 291217  2018           HI         Hawaii       NVSS  Cardiovascular Disease
# ...      ...          ...            ...        ...                     ...
# 387502  2018           WA     Washington       NVSS  Cardiovascular Disease
# 387794  2018           WI      Wisconsin       NVSS  Cardiovascular Disease
# 388018  2018           WV  West Virginia       NVSS  Cardiovascular Disease
# 388306  2018           WV  West Virginia       NVSS  Cardiovascular Disease
# 388941  2018           WY        Wyoming       NVSS  Cardiovascular Disease
#
# ...

# %%
Heart_issues_group = Heart_issues.groupby('LocationDesc').mean(numeric_only=True).reset_index()
Heart_issues_group
# Out:
#             LocationDesc    Year  DataValueAlt  LowConfidenceLimit  \
# 0                Alabama  2018.0    134.560606          126.284848
# 1                 Alaska  2018.0    113.368750           93.096875
# 2                Arizona  2018.0     97.202500           90.652500
# 3               Arkansas  2018.0    144.662500          134.284375
# 4             California  2018.0    110.832500          107.362500
# 5               Colorado  2018.0     99.471795           89.346154
# 6            Connecticut  2018.0     93.222857           86.534286
# 7               Delaware  2018.0    117.975000          106.789286
# 8   District of Columbia  2018.0    123.259259          110.848148
# 9                Florida  2018.0     97.207692           93.302564
# 10               Georgia  2018.0    108.520000          103.968571
# 11                Hawaii  2018.0    106.593548           94.670968
# 12                 Idaho  2018.0    112.217241           99.196552
# ...

# %%
wealth_and_Heart_issues = wealth_data_state.merge(Heart_issues_group, left_on='STATE', right_on='LocationDesc', how='left')
wealth_and_Heart_issues
# Out:
#                    STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  \
# 0                Alabama      AL   4864680   829400   147898     477474
# 1                 Alaska      AK    738516    77865    28067     102956
# 2                Arizona      AZ   6946685  1092192   210214     748306
# 3               Arkansas      AR   2990671   510337    75774     265434
# 4             California      CA  39148760  5487141  1321502    3280167
# 5               Colorado      CO   5531141   590504   139326     441850
# 6            Connecticut      CT   3581504   348449   125909     196809
# 7               Delaware      DE    949495   109798    28501      56491
# 8   District Of Columbia      DC    684498   109497    29373      27088
# 9                Florida      FL  20598139  2983851   622978    2744513
# 10               Georgia      GA  10297484  1607714   322854    1389541
# 11                Hawaii      HI   1422029   137516    32036      55624
# ...

# %%
wealth_and_Heart_issues['PCNT_POV'].corr(wealth_and_Heart_issues['DataValueAlt'])
# Out:
# 0.5422602134760495

# %%
sns.regplot(x=wealth_and_Heart_issues["DataValueAlt"], y=wealth_and_Heart_issues["PCNT_POV"], color="tan", line_kws={"color": "black", "linewidth": 1.5})
plt.title("Poverty Percentage vs Heart Disease Mortality")
plt.xlabel('Heart Disease Mortality Per 100,000')
plt.ylabel('Poverty Percentage')
plt.savefig('pov_vs_hear_disease')
plt.show()

# %%
wealth_and_Heart_issues['PCNT_UNINSUR'].corr(wealth_and_Heart_issues['DataValueAlt'])
# Out:
# 0.21128506007224762

# %%
sns.regplot(x=wealth_and_Heart_issues["DataValueAlt"], y=wealth_and_Heart_issues["PCNT_UNINSUR"], color="tan", line_kws={"color": "black", "linewidth": 1.5})
plt.title("Uninsured Percentage vs Heart Disease Mortality")
plt.xlabel('Heart Disease Mortality Per 100,000')
plt.ylabel('Percentage Unisured')
plt.savefig('UNINSUR_vs_heart_disease')
plt.show()

# %%
#chronic_disease_2018.to_csv('chronic_disease_2018.csv')

# %%
Life_expectancy_birth = chronic_disease_2018[chronic_disease_2018['Question'] == "Life expectancy at birth"]
Life_expectancy_birth
# Out:
#         Year LocationAbbr    LocationDesc       DataSource  \
# 462254  2018           NM      New Mexico  NVSS, Mortality
# 463305  2018           ND    North Dakota  NVSS, Mortality
# 466999  2018           UT            Utah  NVSS, Mortality
# 474547  2018           UT            Utah  NVSS, Mortality
# 475384  2018           MI        Michigan  NVSS, Mortality
# ...      ...          ...             ...              ...
# 503023  2018           SC  South Carolina  NVSS, Mortality
# 503041  2018           IN         Indiana  NVSS, Mortality
# 503155  2018           RI    Rhode Island  NVSS, Mortality
# 503274  2018           VT         Vermont  NVSS, Mortality
# 503744  2018           AL         Alabama  NVSS, Mortality
#
#                          Topic                  Question DataValueUnit  \
# 462254  Overarching Conditions  Life expectancy at birth         Years
# 463305  Overarching Conditions  Life expectancy at birth         Years
# ...

# %%
Life_expectancy_birth_group = Life_expectancy_birth.groupby('LocationDesc').mean(numeric_only=True).reset_index()

# %%
Life_expectancy_birth_group['DataValueAlt'] = Life_expectancy_birth_group['DataValueAlt'].round()

# %%
Life_expectancy_birth_group
# Out:
#             LocationDesc    Year  DataValueAlt  LowConfidenceLimit  \
# 0                Alabama  2018.0          75.0           74.900000
# 1                 Alaska  2018.0          78.0           77.633333
# 2                Arizona  2018.0          79.0           78.600000
# 3               Arkansas  2018.0          76.0           75.400000
# 4             California  2018.0          81.0           80.700000
# 5               Colorado  2018.0          80.0           79.866667
# 6            Connecticut  2018.0          80.0           80.233333
# 7               Delaware  2018.0          78.0           77.366667
# 8   District of Columbia  2018.0          78.0           77.133333
# 9                Florida  2018.0          79.0           78.800000
# 10               Georgia  2018.0          77.0           77.100000
# 11                Hawaii  2018.0          81.0           80.733333
# 12                 Idaho  2018.0          79.0           78.766667
# ...

# %%
wealth_data_state.head(5)
# Out:
#         STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  PCNT_POV  \
# 0     Alabama      AL   4864680   829400   147898     477474      17.0
# 1      Alaska      AK    738516    77865    28067     102956      11.0
# 2     Arizona      AZ   6946685  1092192   210214     748306      16.0
# 3    Arkansas      AR   2990671   510337    75774     265434      17.0
# 4  California      CA  39148760  5487141  1321502    3280167      14.0
#
#    PCNT_UNEMP  PCNT_UNINSUR
# 0         3.0          10.0
# 1         4.0          14.0
# 2         3.0          11.0
# 3         3.0           9.0
# 4         3.0           8.0

# %%
wealth_and_life_at_birth = wealth_data_state.merge(Life_expectancy_birth_group, left_on='STATE', right_on='LocationDesc', how='left')

# %%
wealth_and_life_at_birth
# Out:
#                    STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  \
# 0                Alabama      AL   4864680   829400   147898     477474
# 1                 Alaska      AK    738516    77865    28067     102956
# 2                Arizona      AZ   6946685  1092192   210214     748306
# 3               Arkansas      AR   2990671   510337    75774     265434
# 4             California      CA  39148760  5487141  1321502    3280167
# 5               Colorado      CO   5531141   590504   139326     441850
# 6            Connecticut      CT   3581504   348449   125909     196809
# 7               Delaware      DE    949495   109798    28501      56491
# 8   District Of Columbia      DC    684498   109497    29373      27088
# 9                Florida      FL  20598139  2983851   622978    2744513
# 10               Georgia      GA  10297484  1607714   322854    1389541
# 11                Hawaii      HI   1422029   137516    32036      55624
# ...

# %%
#wealth_and_life_at_birth.to_csv('wealth_and_life_at_birth.csv')

# %%
sns.scatterplot(x=wealth_and_life_at_birth["DataValueAlt"], y=wealth_and_life_at_birth["PCNT_POV"], color="tan", edgecolor="black", alpha=0.5, s=75)
plt.title("Poverty Percentage vs Life Expectancy at Birth")
plt.xlabel('Age at Death')
plt.ylabel('Poverty Percentage')
plt.savefig('pov_vs_life_expectancy_birth')
plt.show()

# %%
wealth_and_life_at_birth['PCNT_POV'].corr(wealth_and_life_at_birth['DataValueAlt'])
# Out:
# -0.7268107745468183

# %%
sns.regplot(x=wealth_and_life_at_birth["DataValueAlt"], y=wealth_and_life_at_birth["PCNT_POV"], color="tan", line_kws={"color": "black", "linewidth": 1.5})
plt.title("Poverty Percentage vs Life Expectancy at Birth")
plt.xlabel('Age at Death')
plt.ylabel('Poverty Percentage')
plt.savefig('pov_vs_life_expectancy_birth')
plt.show()

# %%
sns.scatterplot(x=wealth_and_life_at_birth["PCNT_UNINSUR"], y=wealth_and_life_at_birth["DataValueAlt"])
plt.show()

# %%
wealth_and_life_at_birth['PCNT_UNINSUR'].corr(wealth_and_life_at_birth['DataValueAlt'])
# Out:
# -0.36131248346014566

# %%
sns.regplot(x=wealth_and_life_at_birth["DataValueAlt"], y=wealth_and_life_at_birth["PCNT_UNINSUR"], color="tan", line_kws={"color": "black", "linewidth": 1.5})
plt.title("Uninsured Percentage vs Life Expectancy at Birth")
plt.xlabel('Age at Death')
plt.ylabel('Percentage Unisured')
plt.savefig('UNINSUR_vs_life_expectancy_birth')
plt.show()

# %%
sns.scatterplot(x=wealth_and_life_at_birth["DataValueAlt"], y=wealth_and_life_at_birth["PCNT_UNEMP"])
plt.show()

# %%
wealth_and_life_at_birth['PCNT_UNEMP'].corr(wealth_and_life_at_birth['DataValueAlt'])
# Out:
# -0.3320668277064279

# %%
sns.scatterplot(x=wealth_and_life_at_birth["DataValueAlt"], y=wealth_and_life_at_birth["PCNT_UNEMP"], color="tan")
plt.title("Unemployed Percentage vs Life Expectancy at Birth")
plt.xlabel('Age at Death')
plt.ylabel('Percentage Unempoyed')
plt.savefig('PCNT_UNEMP_vs_life_expectancy_birth')
plt.show()

# %%
Life_expectancy_birth
# Out:
#         Year LocationAbbr    LocationDesc       DataSource  \
# 462254  2018           NM      New Mexico  NVSS, Mortality
# 463305  2018           ND    North Dakota  NVSS, Mortality
# 466999  2018           UT            Utah  NVSS, Mortality
# 474547  2018           UT            Utah  NVSS, Mortality
# 475384  2018           MI        Michigan  NVSS, Mortality
# ...      ...          ...             ...              ...
# 503023  2018           SC  South Carolina  NVSS, Mortality
# 503041  2018           IN         Indiana  NVSS, Mortality
# 503155  2018           RI    Rhode Island  NVSS, Mortality
# 503274  2018           VT         Vermont  NVSS, Mortality
# 503744  2018           AL         Alabama  NVSS, Mortality
#
#                          Topic                  Question DataValueUnit  \
# 462254  Overarching Conditions  Life expectancy at birth         Years
# 463305  Overarching Conditions  Life expectancy at birth         Years
# ...

# %%
Life_expectancy_65 = chronic_disease_2018[chronic_disease_2018['Question'] == "Life expectancy at age 65 years"]

# %%
Life_expectancy_65
# Out:
#         Year LocationAbbr          LocationDesc       DataSource  \
# 467867  2018           GA               Georgia  NVSS, Mortality
# 470841  2018           AR              Arkansas  NVSS, Mortality
# 471323  2018           DE              Delaware  NVSS, Mortality
# 489147  2018           NV                Nevada  NVSS, Mortality
# 489196  2018           IL              Illinois  NVSS, Mortality
# ...      ...          ...                   ...              ...
# 503656  2018           AK                Alaska  NVSS, Mortality
# 503695  2018           CT           Connecticut  NVSS, Mortality
# 503746  2018           TN             Tennessee  NVSS, Mortality
# 503785  2018           CO              Colorado  NVSS, Mortality
# 503882  2018           DC  District of Columbia  NVSS, Mortality
#
#                          Topic                         Question DataValueUnit  \
# 467867  Overarching Conditions  Life expectancy at age 65 years         Years
# ...

# %%
Life_expectancy_65_group = Life_expectancy_65.groupby('LocationDesc').mean(numeric_only=True).reset_index()

# %%
wealth_and_life_at_65 = wealth_data_state.merge(Life_expectancy_65_group, left_on='STATE', right_on='LocationDesc', how='left')

# %%
sns.scatterplot(x=wealth_and_life_at_65["DataValueAlt"], y=wealth_and_life_at_65["PCNT_POV"], color="tan", edgecolor="black", alpha=0.5, s=75)
plt.title("Poverty Percentage vs Life Expectancy at 65")
plt.xlabel('Age at Death')
plt.ylabel('Poverty Percentage')
plt.savefig('life_expectancy_65')
plt.show()

# %%
wealth_and_life_at_65['PCNT_POV'].corr(wealth_and_life_at_65['DataValueAlt'])
# Out:
# -0.6827135014728442

# %%
sns.regplot(x=wealth_and_life_at_65["DataValueAlt"], y=wealth_and_life_at_65["PCNT_POV"], color="tan", line_kws={"color": "black", "linewidth": 1.5})
plt.title("Poverty Percentage vs Life Expectancy at 65")
plt.xlabel('Years to Death')
plt.ylabel('Poverty Percentage')
plt.savefig('life_expectancy_65')
plt.show()

# %%
sns.scatterplot(x=wealth_and_life_at_65["E_UNINSUR"], y=wealth_and_life_at_65["DataValueAlt"])
plt.show()

# %%
sns.scatterplot(x=wealth_and_life_at_65["E_UNEMP"], y=wealth_and_life_at_65["DataValueAlt"])
plt.show()

# %%
chronic_disease_2018_state2 = chronic_disease_2018.groupby(['LocationAbbr', 'LocationDesc']).mean(numeric_only=True).reset_index()

# %%
chronic_disease_2018_state2
# Out:
#    LocationAbbr          LocationDesc    Year  DataValueAlt  \
# 0            AK                Alaska  2018.0    129.486189
# 1            AL               Alabama  2018.0    482.824933
# 2            AR              Arkansas  2018.0    908.163005
# 3            AZ               Arizona  2018.0   1337.984155
# 4            CA            California  2018.0   1756.681737
# 5            CO              Colorado  2018.0    880.349120
# 6            CT           Connecticut  2018.0    276.231769
# 7            DC  District of Columbia  2018.0    157.372074
# 8            DE              Delaware  2018.0    214.465194
# 9            FL               Florida  2018.0   5272.503975
# 10           GA               Georgia  2018.0   2220.660484
# 11           HI                Hawaii  2018.0    108.271348
# 12           IA                  Iowa  2018.0    819.361356
# 13           ID                 Idaho  2018.0    169.283467
# 14           IL              Illinois  2018.0    930.676148
# ...

# %%
top_5_states_chronic_disease = chronic_disease_2018_state2.sort_values('DataValueAlt', ascending=False)
top_5_states_chronic_disease.head(5)
# Out:
#    LocationAbbr    LocationDesc    Year  DataValueAlt  LowConfidenceLimit  \
# 9            FL         Florida  2018.0   5272.503975           54.182368
# 27           NC  North Carolina  2018.0   2548.908657           64.048339
# 10           GA         Georgia  2018.0   2220.660484           56.564482
# 22           MI        Michigan  2018.0   2035.417403           57.735891
# 31           NJ      New Jersey  2018.0   2007.651808           54.133203
#
#     HighConfidenceLimit
# 9             64.219274
# 27            74.981314
# 10            65.728008
# 22            68.524209
# 31            65.624002

# %%
bottom_5_states_chronic_disease = chronic_disease_2018_state2.sort_values('DataValueAlt', ascending=True)
bottom_5_states_chronic_disease.head(5)
# Out:
#    LocationAbbr  LocationDesc    Year  DataValueAlt  LowConfidenceLimit  \
# 50           WY       Wyoming  2018.0     97.908721           48.183651
# 11           HI        Hawaii  2018.0    108.271348           41.391572
# 28           ND  North Dakota  2018.0    109.611791           50.910270
# 0            AK        Alaska  2018.0    129.486189           46.232245
# 26           MT       Montana  2018.0    132.256256           50.116636
#
#     HighConfidenceLimit
# 50            64.859309
# 11            54.608619
# 28            67.868743
# 0             64.280827
# 26            66.299674

# %%
chronic_disease_2018_state = chronic_disease_2018.groupby(['LocationAbbr', 'LocationDesc', 'Topic', 'StratificationCategoryID1', 'StratificationID1']).mean(['DataValue','DataValueAlt', 'LowConfidenceLimit', 'HighConfidenceLimit']).reset_index()

# %%
chronic_disease_2018_state
# Out:
#      LocationAbbr LocationDesc    Topic StratificationCategoryID1  \
# 0              AK       Alaska  Alcohol                    GENDER
# 1              AK       Alaska  Alcohol                    GENDER
# 2              AK       Alaska  Alcohol                   OVERALL
# 3              AK       Alaska  Alcohol                      RACE
# 4              AK       Alaska  Alcohol                      RACE
# ...           ...          ...      ...                       ...
# 7738           WY      Wyoming  Tobacco                      RACE
# 7739           WY      Wyoming  Tobacco                      RACE
# 7740           WY      Wyoming  Tobacco                      RACE
# 7741           WY      Wyoming  Tobacco                      RACE
# 7742           WY      Wyoming  Tobacco                      RACE
#
#      StratificationID1    Year  DataValueAlt  LowConfidenceLimit  \
# 0                 GENF  2018.0     13.600000            6.820000
# ...

# %%
death_count = pd.read_csv(r'C:\Users\hayli\Documents\DA12\Capstone Project\nss-capstone\data\Weekly_Counts_of_Deaths_by_State_and_Select_Causes__2014-2019_20241003.csv')

# %%
death_count
# Out:
#       Jurisdiction of Occurrence  MMWR Year  MMWR Week Week Ending Date  \
# 0                        Florida       2014         43       10/25/2014
# 1                        Florida       2014         44       11/01/2014
# 2                        Florida       2014         45       11/08/2014
# 3                        Florida       2014         46       11/15/2014
# 4                        Florida       2014         47       11/22/2014
# ...                          ...        ...        ...              ...
# 16897                Puerto Rico       2019         48       11/30/2019
# 16898                Puerto Rico       2019         49       12/07/2019
# 16899                Puerto Rico       2019         50       12/14/2019
# 16900                Puerto Rico       2019         51       12/21/2019
# 16901                Puerto Rico       2019         52       12/28/2019
#
#        All  Cause  Natural Cause  Septicemia (A40-A41)  \
# ...

# %%
death_count = death_count.rename(columns={'Jurisdiction of Occurrence' : 'State', 'MMWR Year' : 'Year', 'MMWR Week': 'Week', 'Week Ending Date' : 'Week_End_Date', 'All  Cause' : 'All_Cause',  'Natural Cause' : 'Natural_Cause', 'Septicemia (A40-A41)' : 'Septicemia', 'Malignant neoplasms (C00-C97)' : 'Malignant_Neoplasms', 'Diabetes mellitus (E10-E14)' : 'Diabetes', 'Alzheimer disease (G30)' : 'Alzheimer', 'Influenza and pneumonia (J10-J18)' : 'Flu_and_Pneumonia', 'Chronic lower respiratory diseases (J40-J47)' : 'Lower_Resp_Diseases', 'Other diseases of respiratory system (J00-J06,J30-J39,J67,J70-J98)' : 'Other_Resp_Diseases',	'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)' : 'Nephritis', 'Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified (R00-R99)' : 'Abnormal_Findings',	'Diseases of heart (I00-I09,I11,I13,I20-I51)' : 'Heart_Disease',	'Cerebrovascular diseases (I60-I69)' : 'Cerebrovascular_diseases'})

# %%
death_count
# Out:
#              State  Year  Week Week_End_Date  All_Cause  Natural_Cause  \
# 0          Florida  2014    43    10/25/2014       3381           3149
# 1          Florida  2014    44    11/01/2014       3501           3261
# 2          Florida  2014    45    11/08/2014       3646           3369
# 3          Florida  2014    46    11/15/2014       3615           3346
# 4          Florida  2014    47    11/22/2014       3672           3383
# ...            ...   ...   ...           ...        ...            ...
# 16897  Puerto Rico  2019    48    11/30/2019        619            568
# 16898  Puerto Rico  2019    49    12/07/2019        555            530
# 16899  Puerto Rico  2019    50    12/14/2019        526            492
# 16900  Puerto Rico  2019    51    12/21/2019        577            533
# 16901  Puerto Rico  2019    52    12/28/2019        553            511
#
#        Septicemia  Malignant_Neoplasms  Diabetes  Alzheimer  ...  flag_neopl  \
# ...

# %%
death_count_short = death_count[['State', 'Year', 'All_Cause', 'Natural_Cause', 'Septicemia', 'Malignant_Neoplasms', 'Diabetes', 'Alzheimer', 'Flu_and_Pneumonia', 'Lower_Resp_Diseases', 'Other_Resp_Diseases','Nephritis', 'Abnormal_Findings', 'Heart_Disease', 'Cerebrovascular_diseases']]

# %%
death_count_all_group = death_count_short.groupby(['State', 'Year']).sum().reset_index()
death_count_all_group
# Out:
#        State  Year  All_Cause  Natural_Cause  Septicemia  Malignant_Neoplasms  \
# 0    Alabama  2014      50229          46589      1031.0              10245.0
# 1    Alabama  2015      50661          46809      1017.0              10073.0
# 2    Alabama  2016      51130          47006       993.0              10165.0
# 3    Alabama  2017      52132          47890      1005.0              10152.0
# 4    Alabama  2018      53146          49052      1003.0              10383.0
# ..       ...   ...        ...            ...         ...                  ...
# 319  Wyoming  2015       4467           3877         0.0                862.0
# 320  Wyoming  2016       4325           3798         0.0                862.0
# 321  Wyoming  2017       4361           3834         0.0                887.0
# 322  Wyoming  2018       4640           4112         0.0                916.0
# 323  Wyoming  2019       4672           4070         0.0                895.0
#
# ...

# %%
death_count_all_group['PCNT_Heart_Disease'] = round(death_count_all_group['Heart_Disease'] / death_count_all_group['All_Cause']*100)

# %%
death_count_all_group['PCNT_Lower_Resp_Diseases'] = round(death_count_all_group['Lower_Resp_Diseases'] / death_count_all_group['All_Cause']*100)

# %%
death_count_all_group['PCNT_Malignant_Neoplasms'] = round(death_count_all_group['Malignant_Neoplasms'] / death_count_all_group['All_Cause']*100)

# %%
#death_count_all_group.to_csv('death_count_all_group.csv')

# %%
death_count_2018 = death_count_short[death_count_short['Year'] == 2018]

# %%
death_count_2018
# Out:
#                State  Year  All_Cause  Natural_Cause  Septicemia  \
# 244    United States  2018      66142          61016      1066.0
# 245    United States  2018      67501          62573      1044.0
# 246    United States  2018      64650          60052      1040.0
# 247    United States  2018      62784          58011       960.0
# 248    United States  2018      60980          56268       979.0
# ...              ...   ...        ...            ...         ...
# 16845    Puerto Rico  2018        535            490         NaN
# 16846    Puerto Rico  2018        590            547        18.0
# 16847    Puerto Rico  2018        614            574        15.0
# 16848    Puerto Rico  2018        573            543        11.0
# 16849    Puerto Rico  2018        625            596        15.0
#
#        Malignant_Neoplasms  Diabetes  Alzheimer  Flu_and_Pneumonia  \
# 244                11920.0    2110.0     2958.0             2509.0
# ...

# %%
death_count_2018_group = death_count_2018.groupby(['State', 'Year']).sum().reset_index()

# %%
death_count_2018_group
# Out:
#                    State  Year  All_Cause  Natural_Cause  Septicemia  \
# 0                Alabama  2018      53146          49052      1003.0
# 1                 Alaska  2018       4289           3614         0.0
# 2                Arizona  2018      59495          53076       131.0
# 3               Arkansas  2018      31744          29318       238.0
# 4             California  2018     268145         247074      1602.0
# 5               Colorado  2018      39007          34225       294.0
# 6            Connecticut  2018      31333          28697       445.0
# 7               Delaware  2018       9449           8598         0.0
# 8   District of Columbia  2018       6127           5363         0.0
# 9                Florida  2018     205757         187388      2489.0
# 10               Georgia  2018      85356          78389      1681.0
# 11                Hawaii  2018      11427          10499         0.0
# 12                 Idaho  2018      14114          12729         0.0
# ...

# %%
death_count_2018_group['death_count'] = death_count_2018_group['Septicemia'] + death_count_2018_group['Malignant_Neoplasms'] + death_count_2018_group['Diabetes'] + death_count_2018_group['Alzheimer'] + death_count_2018_group['Flu_and_Pneumonia'] + death_count_2018_group['Lower_Resp_Diseases'] + death_count_2018_group['Other_Resp_Diseases'] + death_count_2018_group['Nephritis'] + death_count_2018_group['Abnormal_Findings'] + death_count_2018_group['Heart_Disease'] + death_count_2018_group['Cerebrovascular_diseases']

# %%
death_count_2018_group['PCNT_Natural'] = round(death_count_2018_group['Natural_Cause'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Septicemia'] = round(death_count_2018_group['Septicemia'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Malignant_Neoplasms'] = round(death_count_2018_group['Malignant_Neoplasms'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Diabetes'] = round(death_count_2018_group['Diabetes'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Alzheimer'] = round(death_count_2018_group['Alzheimer'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Flu_and_Pneumonia'] = round(death_count_2018_group['Flu_and_Pneumonia'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Lower_Resp_Diseases'] = round(death_count_2018_group['Lower_Resp_Diseases'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Other_Resp_Diseases'] = round(death_count_2018_group['Other_Resp_Diseases'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Nephritis'] = round(death_count_2018_group['Nephritis'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Abnormal_Findings'] = round(death_count_2018_group['Abnormal_Findings'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Heart_Disease'] = round(death_count_2018_group['Heart_Disease'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group['PCNT_Cerebrovascular_diseases'] = round(death_count_2018_group['Cerebrovascular_diseases'] / death_count_2018_group['All_Cause']*100)

# %%
death_count_2018_group[['State', 'death_count', 'All_Cause', 'Natural_Cause']]
# Out:
#                    State  death_count  All_Cause  Natural_Cause
# 0                Alabama      39012.0      53146          49052
# 1                 Alaska       1656.0       4289           3614
# 2                Arizona      40322.0      59495          53076
# 3               Arkansas      22419.0      31744          29318
# 4             California     195078.0     268145         247074
# 5               Colorado      24131.0      39007          34225
# 6            Connecticut      20285.0      31333          28697
# 7               Delaware       5248.0       9449           8598
# 8   District of Columbia       2954.0       6127           5363
# 9                Florida     145371.0     205757         187388
# 10               Georgia      61521.0      85356          78389
# 11                Hawaii       6525.0      11427          10499
# 12                 Idaho       8554.0      14114          12729
# 13              Illinois      75513.0     106459          98005
# ...

# %%
death_count_2018_group
# Out:
#                    State  Year  All_Cause  Natural_Cause  Septicemia  \
# 0                Alabama  2018      53146          49052      1003.0
# 1                 Alaska  2018       4289           3614         0.0
# 2                Arizona  2018      59495          53076       131.0
# 3               Arkansas  2018      31744          29318       238.0
# 4             California  2018     268145         247074      1602.0
# 5               Colorado  2018      39007          34225       294.0
# 6            Connecticut  2018      31333          28697       445.0
# 7               Delaware  2018       9449           8598         0.0
# 8   District of Columbia  2018       6127           5363         0.0
# 9                Florida  2018     205757         187388      2489.0
# 10               Georgia  2018      85356          78389      1681.0
# 11                Hawaii  2018      11427          10499         0.0
# 12                 Idaho  2018      14114          12729         0.0
# ...

# %%
#death_count_2018_group.to_csv('death_count_2018_group.csv')

# %%
death_count_2018_group = death_count_2018_group[death_count_2018_group['State'] != 'United States']

# %%
death_count_2018_group = death_count_2018_group[death_count_2018_group['State'] != 'Puerto Rico']

# %%
death_count_2018_group = death_count_2018_group[death_count_2018_group['State'] != 'New York City']

# %%
death_count_2018_group
# Out:
#                    State  Year  All_Cause  Natural_Cause  Septicemia  \
# 0                Alabama  2018      53146          49052      1003.0
# 1                 Alaska  2018       4289           3614         0.0
# 2                Arizona  2018      59495          53076       131.0
# 3               Arkansas  2018      31744          29318       238.0
# 4             California  2018     268145         247074      1602.0
# 5               Colorado  2018      39007          34225       294.0
# 6            Connecticut  2018      31333          28697       445.0
# 7               Delaware  2018       9449           8598         0.0
# 8   District of Columbia  2018       6127           5363         0.0
# 9                Florida  2018     205757         187388      2489.0
# 10               Georgia  2018      85356          78389      1681.0
# 11                Hawaii  2018      11427          10499         0.0
# 12                 Idaho  2018      14114          12729         0.0
# ...

# %%
death_count_2018_group.columns
# Out:
# Index(['State', 'Year', 'All_Cause', 'Natural_Cause', 'Septicemia',
#        'Malignant_Neoplasms', 'Diabetes', 'Alzheimer', 'Flu_and_Pneumonia',
#        'Lower_Resp_Diseases', 'Other_Resp_Diseases', 'Nephritis',
#        'Abnormal_Findings', 'Heart_Disease', 'Cerebrovascular_diseases',
#        'death_count', 'PCNT_Natural', 'PCNT_Septicemia',
#        'PCNT_Malignant_Neoplasms', 'PCNT_Diabetes', 'PCNT_Alzheimer',
#        'PCNT_Flu_and_Pneumonia', 'PCNT_Lower_Resp_Diseases',
#        'PCNT_Other_Resp_Diseases', 'PCNT_Nephritis', 'PCNT_Abnormal_Findings',
#        'PCNT_Heart_Disease', 'PCNT_Cerebrovascular_diseases'],
#       dtype='object')

# %%
death_count_pcnt = death_count_2018_group[['State', 'PCNT_Septicemia', 'PCNT_Malignant_Neoplasms',
       'PCNT_Diabetes', 'PCNT_Alzheimer', 'PCNT_Flu_and_Pneumonia',
       'PCNT_Lower_Resp_Diseases', 'PCNT_Other_Resp_Diseases',
       'PCNT_Nephritis', 'PCNT_Abnormal_Findings', 'PCNT_Heart_Disease',
       'PCNT_Cerebrovascular_diseases']]

# %%
death_count_pcnt.head(20)
# Out:
#                    State  PCNT_Septicemia  PCNT_Malignant_Neoplasms  \
# 0                Alabama              2.0                      20.0
# 1                 Alaska              0.0                      21.0
# 2                Arizona              0.0                      20.0
# 3               Arkansas              1.0                      20.0
# 4             California              1.0                      22.0
# 5               Colorado              1.0                      20.0
# 6            Connecticut              1.0                      21.0
# 7               Delaware              0.0                      22.0
# 8   District of Columbia              0.0                      22.0
# 9                Florida              1.0                      22.0
# 10               Georgia              2.0                      21.0
# 11                Hawaii              0.0                      21.0
# 12                 Idaho              0.0                      22.0
# ...

# %%
#death_count_pcnt.to_csv('death_count_pcnt.csv')

# %%
Top_5_death_counts = death_count_2018_group.sort_values('PCNT_Natural', ascending=False).head(5)

# %%
Top_5_death_counts
# Out:
#        State  Year  All_Cause  Natural_Cause  Septicemia  Malignant_Neoplasms  \
# 27  Nebraska  2018      17103          15934         0.0               3567.0
# 32  New York  2018     100301          93599      1308.0              21446.0
# 15      Iowa  2018      30112          28009        69.0               6382.0
# 0    Alabama  2018      53146          49052      1003.0              10383.0
# 13  Illinois  2018     106459          98005      1702.0              23298.0
#
#     Diabetes  Alzheimer  Flu_and_Pneumonia  Lower_Resp_Diseases  ...  \
# 27     507.0      627.0              201.0               1160.0  ...
# 32    2515.0     2474.0             2690.0               5381.0  ...
# 15     876.0     1444.0              516.0               1857.0  ...
# 0     1132.0     2566.0             1237.0               3534.0  ...
# 13    2790.0     3976.0             2510.0               5463.0  ...
#
#     PCNT_Malignant_Neoplasms  PCNT_Diabetes  PCNT_Alzheimer  \
# ...

# %%
bottom_5_death_counts = death_count_2018_group.sort_values('PCNT_Natural', ascending=True).head(5)

# %%
bottom_5_death_counts
# Out:
#                    State  Year  All_Cause  Natural_Cause  Septicemia  \
# 1                 Alaska  2018       4289           3614         0.0
# 31            New Mexico  2018      18354          16042         0.0
# 5               Colorado  2018      39007          34225       294.0
# 47                  Utah  2018      18931          16743         0.0
# 8   District of Columbia  2018       6127           5363         0.0
#
#     Malignant_Neoplasms  Diabetes  Alzheimer  Flu_and_Pneumonia  \
# 1                 884.0       0.0        0.0                0.0
# 31               3542.0     544.0      455.0              155.0
# 5                7869.0     987.0     1655.0              361.0
# 47               3351.0     556.0     1049.0              182.0
# 8                1319.0      11.0        0.0               10.0
#
#     Lower_Resp_Diseases  ...  PCNT_Malignant_Neoplasms  PCNT_Diabetes  \
# 1                   0.0  ...                      21.0            0.0
# ...

# %%
wealth_life_heart = wealth_and_life_at_birth.merge(Heart_issues_group, left_on='STATE', right_on='LocationDesc', how='left')

# %%
wealth_life_heart
# Out:
#                    STATE ST_ABBR  E_TOTPOP    E_POV  E_UNEMP  E_UNINSUR  \
# 0                Alabama      AL   4864680   829400   147898     477474
# 1                 Alaska      AK    738516    77865    28067     102956
# 2                Arizona      AZ   6946685  1092192   210214     748306
# 3               Arkansas      AR   2990671   510337    75774     265434
# 4             California      CA  39148760  5487141  1321502    3280167
# 5               Colorado      CO   5531141   590504   139326     441850
# 6            Connecticut      CT   3581504   348449   125909     196809
# 7               Delaware      DE    949495   109798    28501      56491
# 8   District Of Columbia      DC    684498   109497    29373      27088
# 9                Florida      FL  20598139  2983851   622978    2744513
# 10               Georgia      GA  10297484  1607714   322854    1389541
# 11                Hawaii      HI   1422029   137516    32036      55624
# ...

# %%
wealth_life_heart = wealth_life_heart.drop('LocationDesc_x', axis=1)

# %%
wealth_life_heart = wealth_life_heart.drop('LocationDesc_y', axis=1)

# %%
wealth_life_heart = wealth_life_heart.drop('Year_x', axis=1)

# %%
wealth_life_heart = wealth_life_heart.drop('Year_y', axis=1)

# %%
wealth_life_heart = wealth_life_heart.rename(columns={'DataValueAlt_x' : 'Life_Expectancy', 'LowConfidenceLimit_x' : 'LowConfidenceLimit_Age', 'HighConfidenceLimit_x' : 'HighConfidenceLimit_Age', 'DataValueAlt_y' : 'Heart_Disease_Mortality'})

# %% [markdown]
# wealth_life_heart

# %%
wealth_life_heart.to_csv('wealth_life_heart.csv')
